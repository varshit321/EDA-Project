# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('redbus.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)
df['ratings']=df['ratings'].round(1)

# %%
df
# Out:
#                Bus_Name                       Bus_type from   to pickup_time  \
# 0    IntrCity SmartBus      A/C Seater / Sleeper (2+1)  HYD  VJY       23:50
# 1    IntrCity SmartBus                AC Sleeper (2+1)  HYD  VJY       23:15
# 2    IntrCity SmartBus      A/C Seater / Sleeper (2+1)  HYD  VJY       23:30
# 3           AdFRESHBUS       Electric A/C Seater (2+2)  HYD  VJY       11:00
# 4                NueGo       Electric A/C Seater (2+2)  HYD  VJY       05:00
# ..                  ...                            ...  ...  ...         ...
# 509  National  travels     NON AC Seater / Sleeper 2+1  BLR  CHN       23:40
# 510  National  travels               A/C Sleeper (2+1)  BLR  CHN       14:10
# 511  National  travels               A/C Sleeper (2+1)  BLR  CHN       22:30
# 512        VJS Travels   Bharat Benz A/C Sleeper (2+1)  BLR  CHN       04:30
# 513        RDS Travels   Scania A/C Semi Sleeper (2+2)  BLR  CHN       05:30
#
# ...

# %% [markdown]
# #  Data Visualization

# %%
df.dtypes
# Out:
# Bus_Name         object
# Bus_type         object
# from             object
# to               object
# pickup_time      object
# drop_time        object
# duration          int64
# prices            int64
# ratings         float64
# AC_type          object
# Seater           object
# semi_sleeper     object
# sleeper          object
# dtype: object

# %%
df.isna().sum()
# Out:
# Bus_Name        0
# Bus_type        0
# from            0
# to              0
# pickup_time     0
# drop_time       0
# duration        0
# prices          0
# ratings         0
# AC_type         0
# Seater          0
# semi_sleeper    0
# sleeper         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Univariate

# %% [raw]
# UNIVARIATE PLOTS:
#     1.CONTINOUS:
#         *Histogram    : To check distribution and freqency on Y Axis
#         *Density plot : To check distribution and probabilities on Y Axis
#         *box plot     : To check outlierd
#         *line chart   : To get trend
#
#     2.CATEGORICAL:
#         *Bar plot     : To compare and display the frequencies,counts or proportions
#         *count plot   : The number of occurrences or count of unique values
#         *pie chart    : Percentiles or parts

# %% [markdown]
# ## Bivariate

# %% [raw]
# BIVARIATE PLOTS:
#     1.Continuous vs Continuous:
#         *Scatter plot: Relationship between two variables ,Strength is subjective is disadvantage
#     2.Continuous vs Categorical:
#         *Bar Grap:To compare and display the frequencies,counts or proportions.
#         *Stacked bar chart
#     3.Categorical vs Categorical:
#         *Cross Tab

# %% [markdown]
# ## Multivariate

# %% [raw]
# Multivariate :
#     *Heat map:Quantifies and display relationship betwwen multiple variables
#     *pair plot:Displays relationship between multiple variables

# %% [markdown]
# ### Histogram

# %% [markdown]
# ##### Histogram of Bus Ratings

# %%
sns.set_style('ticks')
plt.figure(figsize=(8,4))
plt.hist(df['ratings'],bins=10,color='red')
plt.xlabel("Ratings")
plt.ylabel("Frequency")
plt.title("Histogram of Bus Ratings")
plt.show()

# %% [raw]
# insights:
#     1.Rating ranges from 1.0 to 5.0
#     2.majority of buses has 4 star rating
#     3.less buses has rating of 1.5 star rating

# %% [markdown]
# ##### Histogram of Bus Rating basesd on AC type

# %%
plt.style.use('classic')
plt.title("Histogram of Bus Rating basesd on AC type")
sns.histplot(data=df,x='ratings',bins=10,color='red',hue='AC_type')
plt.show()

# %% [raw]
# insights:
#     1.this graph describes about ratings of AC type buses
#     2.there are more AC buses than non AC buses,most of ac buses has 4.5 star rating,most of non ac buses has rating 3.75

# %% [markdown]
# ### Density plot

# %% [markdown]
# ##### Density plot of Bus Rating basesd on sleeper type

# %%
plt.style.context('Solarize_Light2')
plt.title("Density plot of Bus Rating basesd on seater type")
sns.kdeplot(data=df,x='ratings',hue='Seater')
plt.show()

# %% [raw]
# insights:
#     1.this density plot describes about ratings of seater buses
#     2.non seater buses has more rating than seater buses

# %% [markdown]
# ##### Density plot of Bus Rating basesd on semi-sleeper type

# %%
sns.set_style('dark')
plt.title("Density of Bus Rating basesd on semi_sleeper type")
sns.kdeplot(data=df,x='ratings',hue='semi_sleeper')
plt.show()

# %% [raw]
# insights:
#     1.this density plot describes about ratings of semi-sleeper buses
#     2.for semi sleeper buses has low ratting when compered to non semi-sleeper buses

# %% [markdown]
# ##### Density plot of Bus Rating basesd on sleeper type

# %%
plt.style.context('ggplot')
sns.displot(data=df,x="ratings",hue='sleeper',kde=True).set(title='Density plot of Bus Rating basesd on sleeper type')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.this is density plot of ratings of sleeper buse
#     2.most of  the sleeper buses has 4 star rating
#     3.most of non sleeper buses has rating of 4.5

# %% [markdown]
# ### box plot

# %% [raw]
# we cannot achieve outliers for the bus data set beacuse outliers can only been drawn, if we are having particular duration and prices but for this particular data set that we are considering has a lot fluctuations(different pickup and drop locations), so we cant achieve outlaiers for this data set

# %% [markdown]
# ### line chart

# %% [raw]
# for line chart graphical represntaion is not achived for the bus data set beacuse line graph can only been drawn, if we are  having particular duration and prices but for this particular data set that we are considering has a lot fluctuations(different pickup and drop locations), so we cant draw line chart for this data set

# %% [markdown]
# ### Bar plot

# %% [markdown]
# ##### barplots for bus_types

# %%
plt.style.context('ggplot')
df['Bus_type'].value_counts().plot(kind='bar').set(title='barplot for bus_types')
plt.show()

# %% [raw]
# insights:
#     1.this bar graph describes about frequencies of bus types
#     2.ac sleeper buses are more in number when compared to other buses.

# %% [markdown]
# ##### Barplots to find average ratings of ac buses

# %%
sns.set_style('dark')
sns.barplot(data=df,x='AC_type',y='ratings').set(title='Barplots to find average ratings of ac buses')
plt.show()

# %% [raw]
# insights:
#     1.this is bargraph describes about actype and ratings of buses
#     2.average ratting of ac buses is 3.7
#     3.average rating of non ac buses is 3.2

# %% [markdown]
# ##### Barplots to find average ratings of sleeper buses

# %%
sns.set_style('ticks')
sns.barplot(data=df,x='sleeper',y='ratings').set(title='Barplots to find average ratings of sleeper buses')
plt.show()

# %% [raw]
# insights:
#     1.this is bargraph describes about sleeper and ratings of buses
#     2.average ratting of sleeper buses is 3.6
#     3.average rating of non sleeper buses is 4

# %% [markdown]
# ##### Barplots to find average ratings of seater buses

# %%
sns.barplot(data=df,x='Seater',y='ratings').set(title='Barplots to find average ratings of seater buses')
plt.show()

# %% [raw]
# insights:
#     1.this is bargraph describes about seater and ratings of buses
#     2.average ratting of seater buses is 3.6
#     3.average rating of non seater buses is 3.7

# %% [markdown]
# ##### Barplots to find average ratings of seater buses

# %%
sns.set_style('darkgrid')
sns.barplot(data=df,x='semi_sleeper',y='ratings').set(title='Barplots to find average ratings of semi_sleeper buses')
plt.show()

# %% [raw]
# insights:
#     1.this is bargraph describes about semi sleeper and ratings of buses
#     2.average ratting of semi-sleeper buses is 3.8
#     3.average rating of non semi-sleeeper buses is 3.6

# %% [markdown]
# ### count_plot

# %% [markdown]
# ##### count plot is used to find count the number of occurences of ac_type

# %%
plt.style.use('dark_background')
sns.countplot(data=df,x='AC_type').set(title=' find count the number of occurences of ac_type')
plt.show()

# %% [raw]
# insights:
#     1.this is count plot for ac_type buses
#     2.in the dataset there are more ac buses than non ac buses
#     3.count of ac buses 384
#     4.count of non ac buses is 41

# %%
df['AC_type'].value_counts()
# Out:
# AC_type
# A/C        405
# NON A/C    109
# Name: count, dtype: int64

# %% [markdown]
# # Bivariate

# %% [markdown]
# ### categorical vs categorical

# %% [markdown]
# ##### A complete data of number  AC type and Seater type buses

# %%
s1=pd.crosstab(df['sleeper'],df['AC_type'])
s2=pd.crosstab(df['semi_sleeper'],df['AC_type'])
s3=pd.crosstab(df['Seater'],df['AC_type'])
s=pd.concat([s1,s2,s3],axis=0)
s.index = ['non sleeper', 'sleeper', 'non semi_sleeper', 'semi_sleeper', 'non seater', 'seater']

# %%
s
# Out:
# AC_type           A/C  NON A/C
# non sleeper        63        9
# sleeper           342      100
# non semi_sleeper  373      107
# semi_sleeper       32        2
# non seater        303       25
# seater            102       84

# %%
s.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ##### Top 5 AC travel bus names

# %%
pd.crosstab(df['Bus_Name'],df['AC_type']).sort_values('A/C',ascending=False).head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='Bus_Name'>

# %% [markdown]
# ##### Top 5 NON AC travel bus names

# %%
pd.crosstab(df['Bus_Name'],df['AC_type']).sort_values('NON A/C',ascending=False).head(5)
# Out:
# AC_type                    A/C  NON A/C
# Bus_Name
# Orange Tours And Travels    25       18
# V Kaveri Travels             7        6
# Sri KVR Travels              2        6
# KKaveri Travels              0        5
# Jayanthi Travels             1        4

# %% [markdown]
# ### Continous Vs Continous

# %% [markdown]
# * Its find relationship between two continous variable
# * Disadvantage:-is subjective (quality),u can't say its quantity,only for 2 variable

# %% [raw]
# graphical represntaion is not achived for the bus data set beacuse Scatter plot can only been drawn, if we are  having particular duration and prices but for this particular data set that we are considering has a lot fluctuations(different pickup and drop locations), so we cant draw scatter plot for this data set

# %% [markdown]
# ## Multi variate

# %% [markdown]
# ### heatplot

# %% [raw]
# for heat plot graphical represntaion is not achived for the bus data set beacuse heat plot can only been drawn, if we are  having particular duration,ratings and prices but for this particular data set that we are considering has a lot fluctuations(different pickup and drop locations), so we cant draw heat plot for this data set

# %% [markdown]
# ### pairplot

# %% [raw]
# for pair plot graphical represntaion is not achived for the bus data set beacuse pair plot can only been drawn, if we are  having particular duration,ratings and prices but for this particular data set that we are considering has a lot fluctuations(different pickup and drop locations), so we cant draw pair plot for this data set

# %% [markdown]
# ## Journeys(Trips)

# %%
#trip1
jr1=df[(df['from']=='HYD') & (df['to']=='VJY')]
#trip2
jr2=df[(df['from']=='HYD') & (df['to']=='BLR') ]
jr2.reset_index(drop=True,inplace=True)
#trip3
jr3=df[(df['from']=='BLR') & (df['to']=='CHN') ]
jr2.reset_index(drop=True,inplace=True)

# %%
jr1
# Out:
#                                 Bus_Name                        Bus_type from  \
# 0                     IntrCity SmartBus       A/C Seater / Sleeper (2+1)  HYD
# 1                     IntrCity SmartBus                 AC Sleeper (2+1)  HYD
# 2                     IntrCity SmartBus       A/C Seater / Sleeper (2+1)  HYD
# 3                            AdFRESHBUS        Electric A/C Seater (2+2)  HYD
# 4                                 NueGo        Electric A/C Seater (2+2)  HYD
# ..                                   ...                             ...  ...
# 204                 SAMANVI CITICONNECT                A/C Sleeper (2+1)  HYD
# 205                         CVR Travels   Non A/C Seater / Sleeper (2+1)  HYD
# 206               BSR Tours And Travels       A/C Seater / Sleeper (2+1)  HYD
# 207                            Ajay Bus   Non A/C Seater / Sleeper (2+1)  HYD
# 208  SRI VEERANJANEYA TOURS AND TRAVELS                A/C Sleeper (2+1)  HYD
#
# ...

# %%
jr2
# Out:
#                    Bus_Name                                 Bus_type from  \
# 0             KSM Roadways   A/C Volvo B11R Multi-Axle Sleeper (2+1)  HYD
# 1    VSR Tours and Travels                         A/C Sleeper (2+1)  HYD
# 2          Jabbar  Travels        Scania AC Multi Axle Sleeper (2+1)  HYD
# 3       AdNovember Travels                A/C Seater / Sleeper (2+1)  HYD
# 4          Jabbar  Travels                      VE A/C Sleeper (2+1)  HYD
# ..                      ...                                      ...  ...
# 168            VRL Travels   Volvo 9600 Multi-Axle A/C Sleeper (2+1)  HYD
# 169            VRL Travels                         A/C Sleeper (2+1)  HYD
# 170            VRL Travels                         A/C Sleeper (2+1)  HYD
# 171            VRL Travels                     NON A/C Sleeper (2+1)  HYD
# 172            VRL Travels                     NON A/C Sleeper (2+1)  HYD
#
#       to pickup_time drop_time  duration  prices  ratings  AC_type Seater  \
# ...

# %%
jr3
# Out:
#                  Bus_Name                                      Bus_type from  \
# 382      KMRL Kalaimakal                     A/C Seater / Sleeper (2+1)  BLR
# 383          V2K Travels                              A/C Sleeper (2+1)  BLR
# 384      Jabbar  Travels   Volvo A/C B11R Multi Axle Semi Sleeper (2+2)  BLR
# 385  AdIntrCity SmartBus                     A/C Seater / Sleeper (2+1)  BLR
# 386      KMRL Kalaimakal                              A/C Sleeper (2+1)  BLR
# ..                    ...                                           ...  ...
# 509    National  travels                    NON AC Seater / Sleeper 2+1  BLR
# 510    National  travels                              A/C Sleeper (2+1)  BLR
# 511    National  travels                              A/C Sleeper (2+1)  BLR
# 512          VJS Travels                  Bharat Benz A/C Sleeper (2+1)  BLR
# 513          RDS Travels                  Scania A/C Semi Sleeper (2+2)  BLR
#
# ...

# %%
jr1.to_csv('jr1.csv')
jr2.to_csv('jr2.csv')
jr3.to_csv('jr3.csv')
